# %% [markdown]
# PG Lab 1- Session 2 - NumPy

# %%
import numpy
numpy.__version__

# %%
list1=[]
list1

# %%
type(list1)

# %%
list2=list(range(10))
list2

# %%
list3=[str(c) for c in list2]
list3

# %%
list4=[1, 10.4, 'H', 'Hrishikesh', True]
list4

# %%
type(list4)

# %%
# Display data type of each element
[type(item) for item in list4]

# %%
# Python array
import array as ar
L = list(range(10))
A = ar.array('i', L)
A

# %%
#Numpy Array
import numpy as np
# integer array:
np.array([1,3,5,2,4])

# %%
# Automatic/ Implicit conversion of values/elements
np.array([10.1,2,3,4])

# %%
#explicit conversion
np.array([1,2,3,4], dtype='float32')

# %%
#[[, ,],[ , ,],[, ,]]
#nested lists result in multi-dimensional arrays
np.array([range(i, i+3) for i in [2,4,6]])

# %%
# Create a length-10 integer array filled with zero
np.zeros(10, dtype=int)

# %%
#Create array of Float
np.zeros((2,5), dtype=float)

# %%
# Create a 3x5 array filled with 3.0
np.full((3, 5), 3.0)

# %%
# Create an array filled with a linear sequence
# Starting at 0, ending at 20, stepping by 2
# (this is similar to the built-in range() function)
np.arange(0,20,2)

# %%
np.arange(0,20,3)

# %%
# 0 to 2 --> 4 elements == 0.0,0.5,1.0,1.5
# Creation of an array of evenly spaced values for the given range
np.linspace(0,1,5)

# %%
# Create a 3x3 array of uniformly distributed
#random values between 0 and 1
np.random.random((3, 4))

# %%
# Create a 3x3 array of normally distributed random values
# with mean 0 and standard deviation 1
np.random.normal(0, 1, (3, 3))

# %%
# Create a 3x3 array of random integers in the interval [0, 10)
np.random.randint(0, 10, (3, 3))

# %%
# Create a 3x3 identity matrix
np.eye(3)

# %%
# Create an uninitialized array of three integers
# The values will be whatever happens to already exist at that memory location
np.empty(3)

# %%
import numpy as np
np.random.seed(40)  # seed for reproducibility
x1 = np.random.randint(50, size=6)  # One-dimensional array
x1

# %%
# seed 100     200     5,6,7
np.random.seed(100)
x2=np.random.randint(200, size=(5,6,7))
x2

# %%
np.random.seed(100)
x3=np.random.randint(200, size=(5,4,2,2))
x3

# %%
np.random.seed(100)
x4=np.random.randint(200, size=(5,4,3,2,2))
x4
